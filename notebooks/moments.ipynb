# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Parametri della distribuzione Gamma
shape, scale = 2., 2.  # parametri della distribuzione

# Generazione di campioni dalla distribuzione Gamma
data = np.random.gamma(shape, scale, 1000)

# Calcolo delle statistiche
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0][0]
variance = np.var(data)
skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

# Output delle statistiche
print(f'Media: {mean}')
print(f'Mediana: {median}')
print(f'Moda: {mode}')
print(f'Varianza: {variance}')
print(f'Skewness: {skewness}')
print(f'Curtosi: {kurtosis}')

# Istogramma della distribuzione
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')
plt.title('Distribuzione Gamma')
plt.xlabel('Valori')
plt.ylabel('Densità')
plt.show()
# Out:
# Media: 3.9441712447602337
# Mediana: 3.2860847749507958
# Moda: 0.05949081787414062
# Varianza: 7.824049680682586
# Skewness: 1.341408670451888
# Curtosi: 2.5313221615363144

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Parametri della distribuzione Gamma
shape, scale = 2., 2.  # parametri della distribuzione

# Generazione di campioni dalla distribuzione Gamma
np.random.seed(0)  # Per rendere il risultato riproducibile
data = np.random.gamma(shape, scale, 1000)

# Calcolo delle statistiche
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0][0]
variance = np.var(data)
skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

# Plot della distribuzione
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Dati')

# Linee verticali per le statistiche
plt.axvline(mean, color='blue', linestyle='--', label=f'Media: {mean:.2f}')
plt.axvline(median, color='red', linestyle='-.', label=f'Mediana: {median:.2f}')

# Titolo e etichette
plt.title('Distribuzione Gamma e Statistiche')
plt.xlabel('Valori')
plt.ylabel('Densità')
plt.legend()
plt.grid(True)
plt.show()

# Output delle statistiche
mean, median, mode, variance, skewness, kurtosis
# Out:
# (3.9311453021789893,
#  3.416742055303599,
#  0.0704438811702896,
#  7.265518624878377,
#  1.358332294792333,
#  2.4079180806130145)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Parametri della distribuzione Gamma
shape, scale = 2., 2.

# Generazione di campioni dalla distribuzione Gamma
np.random.seed(0)
data = np.random.gamma(shape, scale, 1000)

# Calcolo delle statistiche
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0][0]
variance = np.var(data)
skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

# Intervallo di varianza
v = np.sqrt(variance)
variance_interval = [mean - v, mean + v]

# Plot della distribuzione e dell'intervallo di varianza
plt.figure(figsize=(16, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='data')

# Linee verticali per le statistiche
plt.axvline(mean, color='blue', linestyle='--', label=f'Mean ($\\mu$): {mean:.2f}', lw=5)
plt.axvline(median, color='red', linestyle='-.', label=f'Median: {median:.2f}', lw=5)

# Area di varianza
plt.fill_betweenx([0, max(stats.gaussian_kde(data).evaluate(data))], variance_interval[0], variance_interval[1],
                  color='blue', alpha=0.2, label=f'Standard deviation = $\\sqrt{{variance}}$: {v:.2f}')

# Titolo e etichette
plt.title('Example of gamma distribution')
plt.xlabel('X')
plt.ylabel('density')
plt.legend()
plt.grid(False)
plt.show()

# Output delle statistiche
mean, median, mode, variance, skewness, kurtosis
# Out:
# (3.9311453021789893,
#  3.416742055303599,
#  0.0704438811702896,
#  7.265518624878377,
#  1.358332294792333,
#  2.4079180806130145)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def generate_data(kurtosis_type, size=1000):
    if kurtosis_type == 'platykurtic':
        # Uniform distribution: low kurtosis
        return np.random.uniform(low=-3, high=3, size=size)
    elif kurtosis_type == 'leptokurtic':
        # Heavy-tailed distribution (e.g., t-distribution with low df): high kurtosis
        return np.random.standard_t(df=2, size=size)  # df=2 for high kurtosis
    elif kurtosis_type == 'mesokurtic':
        # Normal distribution: kurtosis ≈ 3
        return np.random.normal(loc=0, scale=1, size=size)

def plot_overlayed_distributions():
    size = 1000
    bins = 30  # Number of bins for histogram
    
    # Generate data for each type of kurtosis
    platykurtic_data = generate_data('platykurtic', size)
    mesokurtic_data = generate_data('mesokurtic', size)
    leptokurtic_data = generate_data('leptokurtic', size)
    
    plt.figure(figsize=(12, 8))

    # Plot histograms with different colors and labels
    plt.hist(platykurtic_data, bins=bins, color='blue', alpha=0.5, label='Platykurtic', density=True)
    plt.hist(mesokurtic_data, bins=bins, color='green', alpha=0.5, label='Mesokurtic', density=True)
    plt.hist(leptokurtic_data, bins=bins, color='red', alpha=0.5, label='Leptokurtic', density=True)

    # Plot formatting
    plt.title('Overlayed Histograms of Different Kurtosis Distributions')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.legend(loc='upper right')
    plt.grid(True)
    
    plt.show()

# Plot the overlayed distributions
plot_overlayed_distributions()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, t
from scipy.stats import kurtosis

def plot_continuous_distributions():
    # Define the range for the x-axis
    x = np.linspace(-5, 5, 1000)
    
    # Generate the PDFs for different distributions
    mesokurtic_pdf = norm.pdf(x, loc=0, scale=1)       # Normal distribution: Mesokurtic
    leptokurtic_pdf = t.pdf(x, df=2)                    # T-distribution with df=2: Leptokurtic

    # Calculate kurtosis
    mesokurtic_kurtosis = kurtosis(norm.rvs(size=10000))
    leptokurtic_kurtosis = kurtosis(t.rvs(df=2, size=10000))
    
    plt.figure(figsize=(12, 8))

    # Plot PDFs
    plt.plot(x, mesokurtic_pdf, color='green', label=f'Mesokurtic (Normal)\nKurtosis: {mesokurtic_kurtosis:.2f}', linewidth=8)
    plt.plot(x, leptokurtic_pdf, color='red', label=f'Leptokurtic (t-distribution)\nKurtosis: {leptokurtic_kurtosis:.2f}', linewidth=8)
    
    # Plot formatting
    plt.title('Continuous PDFs of Different Kurtosis Distributions', fontsize=20)
    plt.xlabel('Value')
    plt.ylabel('Density')
    
    # Set legend with a larger font size
    plt.legend(loc='upper right', fontsize=14)
    
    plt.grid(True)
    plt.show()

# Plot the continuous distributions
plot_continuous_distributions()

# %% [raw]
# # from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# ## Table of Contents
# 1. [Imports](#section0)
# 2. [Reading Data with pandas](#section1)
# 3. [pandas' swiss knife](#section2)
# 4. [Data selection](#section3)
# 5. [Data manipulation](#section4)

# %% [markdown]
# # Intro
#
# The `pandas` library is an open source package for handling, manipulating, and analyzing structured data.
#
# Data can be available in multiple formats, such as `.csv` and `.json`. They can be read into and stored in a `DataFrame` object.
#
# A `DataFrame` is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# `DataFrame` is one of the data objects available in `pandas`:
#
# * Axis values can have string **labels**, not just numeric ones.
# * Dataframes can contain columns with **multiple data types**: including integer, float, and string.
#
#
# ![pandas_summary.png](attachment:pandas_summary.png)

# %% [markdown]
# <a id='section0'></a>
# ## 1. Imports

# %%
import pandas as pd

# %% [markdown]
# ---
#
# <a id='section1'></a>
# ## 2. Reading Data with `pandas`
#
# ---
#
# `pandas` has several function to read many data formats: https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
covid_regions_url = "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-regioni/dpc-covid19-ita-regioni.csv"
covid_provinces_url = "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province.csv"

# %% [markdown]
# [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
covid_regions_df = pd.read_csv(covid_regions_url)
covid_provinces_df = pd.read_csv(covid_provinces_url)
# Out:
# /tmp/ipykernel_385974/1885033405.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid_regions_df = pd.read_csv(covid_regions_url)

# %% [markdown]
# ---
#
# <a id='section2'></a>
# ## 3. pandas' swiss knife
#
# __Bunch of panda's methods to start the data inspection.__
#
# This functions/attributes of the pandas dataframe are very usefull, especially during the first data inspection and particularly using a jupyter notebook.
#
# ---

# %% [markdown]
# ### .columns

# %% [markdown]
# [.columns](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html)

# %%
covid_regions_df.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione', 'lat',
#        'long', 'ricoverati_con_sintomi', 'terapia_intensiva',
#        'totale_ospedalizzati', 'isolamento_domiciliare', 'totale_positivi',
#        'variazione_totale_positivi', 'nuovi_positivi', 'dimessi_guariti',
#        'deceduti', 'casi_da_sospetto_diagnostico', 'casi_da_screening',
#        'totale_casi', 'tamponi', 'casi_testati', 'note',
#        'ingressi_terapia_intensiva', 'note_test', 'note_casi',
#        'totale_positivi_test_molecolare',
#        'totale_positivi_test_antigenico_rapido', 'tamponi_test_molecolare',
#        'tamponi_test_antigenico_rapido', 'codice_nuts_1', 'codice_nuts_2'],
#       dtype='object')

# %%
covid_provinces_df.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note', 'codice_nuts_1', 'codice_nuts_2',
#        'codice_nuts_3'],
#       dtype='object')

# %% [markdown]
# ### .head() .tail()

# %% [markdown]
# [.head()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)
#
# [.tail()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)

# %%
covid_regions_df.head(2)
# Out:
#                   data stato  codice_regione denominazione_regione        lat  \
# 0  2020-02-24T18:00:00   ITA              13               Abruzzo  42.351222
# 1  2020-02-24T18:00:00   ITA              17            Basilicata  40.639471
#
#         long  ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# 0  13.398438                       0                  0                     0
# 1  15.805148                       0                  0                     0
#
#    isolamento_domiciliare  ...  note  ingressi_terapia_intensiva  note_test  \
# 0                       0  ...   NaN                         NaN        NaN
# 1                       0  ...   NaN                         NaN        NaN
#
#    note_casi  totale_positivi_test_molecolare  \
# 0        NaN                              NaN
# 1        NaN                              NaN
#
#    totale_positivi_test_antigenico_rapido  tamponi_test_molecolare  \
# 0                                     NaN                      NaN
# 1                                     NaN                      NaN
#
#    tamponi_test_antigenico_rapido  codice_nuts_1  codice_nuts_2
# 0                             NaN            NaN            NaN
# 1                             NaN            NaN            NaN
#
# [2 rows x 30 columns]

# %%
covid_regions_df.tail(2)
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 33871  2024-07-24T17:00:00   ITA               2         Valle d'Aosta
# 33872  2024-07-24T17:00:00   ITA               5                Veneto
#
#              lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# 33871  45.737503   7.320149                       0                  0
# 33872  45.434905  12.338452                     196                 13
#
#        totale_ospedalizzati  isolamento_domiciliare  ...  note  \
# 33871                     0                      10  ...   NaN
# 33872                   209                   10387  ...   NaN
#
#        ingressi_terapia_intensiva  note_test  note_casi  \
# 33871                         0.0        NaN        NaN
# 33872                         0.0        NaN        NaN
#
#        totale_positivi_test_molecolare  \
# 33871                          16498.0
# 33872                        1152998.0
#
#        totale_positivi_test_antigenico_rapido  tamponi_test_molecolare  \
# 33871                                 36024.0                 146784.0
# 33872                               1692440.0               12259394.0
#
#        tamponi_test_antigenico_rapido  codice_nuts_1  codice_nuts_2
# 33871                        463376.0            ITC           ITC2
# 33872                      27277759.0            ITH           ITH3
#
# [2 rows x 30 columns]

# %% [markdown]
# ### len() (not pandas)

# %% [markdown]
# [len()](https://docs.python.org/3/library/functions.html#len)

# %%
len(covid_regions_df)
# Out:
# 33873

# %% [markdown]
# ### .unique()  .nunique()

# %% [markdown]
# [.unique()](https://pandas.pydata.org/docs/reference/api/pandas.unique.html)
#
# [.nunique()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nunique.html)

# %%
covid_regions_df['denominazione_regione'].unique()
# Out:
# array(['Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Emilia-Romagna',
#        'Friuli Venezia Giulia', 'Lazio', 'Liguria', 'Lombardia', 'Marche',
#        'Molise', 'P.A. Bolzano', 'P.A. Trento', 'Piemonte', 'Puglia',
#        'Sardegna', 'Sicilia', 'Toscana', 'Umbria', "Valle d'Aosta",
#        'Veneto'], dtype=object)

# %%
covid_regions_df['denominazione_regione'].nunique()
# Out:
# 21

# %% [markdown]
# ### .shape

# %% [markdown]
# [.shape()](https://www.google.com/search?client=safari&rls=en&q=pandas+shape&ie=UTF-8&oe=UTF-8)

# %%
covid_regions_df.shape
# Out:
# (33873, 30)

# %% [markdown]
# ### .describe()

# %% [markdown]
# [.describe()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)

# %%
covid_regions_df.describe()
# Out:
#        codice_regione           lat          long  ricoverati_con_sintomi  \
# count    33873.000000  33873.000000  33873.000000            33873.000000
# mean        11.857143     43.046293     12.225955              363.867682
# std          6.273891      2.488818      2.658987              763.162958
# min          1.000000     38.115697      7.320149                0.000000
# 25%          7.000000     41.125596     11.121231               30.000000
# 50%         12.000000     43.616760     12.388247              123.000000
# 75%         17.000000     45.434905     13.768136              353.000000
# max         22.000000     46.499335     16.867367            12077.000000
#
#        terapia_intensiva  totale_ospedalizzati  isolamento_domiciliare  \
# count       33873.000000          33873.000000            33873.000000
# mean           33.363475            397.231158            17658.410238
# std            84.208792            843.045915            36244.921724
# min             0.000000              0.000000                0.000000
# 25%             1.000000             32.000000              660.000000
# 50%             7.000000            131.000000             4556.000000
# 75%            27.000000            386.000000            16673.000000
# max          1381.000000          13328.000000           574548.000000
#
#        totale_positivi  variazione_totale_positivi  nuovi_positivi  ...  \
# count     33873.000000                33873.000000    33873.000000  ...
# mean      18055.641219                    5.159183      781.348685  ...
# std       36612.216047                 1749.611840     2080.127132  ...
# min           0.000000               -50797.000000     -229.000000  ...
# 25%         742.000000                  -45.000000       18.000000  ...
# 50%        4746.000000                    1.000000      124.000000  ...
# 75%       17154.000000                   69.000000      622.000000  ...
# max      578257.000000                47483.000000    52693.000000  ...
#
#        casi_da_sospetto_diagnostico  casi_da_screening   totale_casi  \
# count                   3402.000000         3402.00000  3.387300e+04
# mean                   16472.772193         6319.39565  6.885498e+05
# std                    32188.413270        15054.35195  9.176060e+05
# min                        0.000000            0.00000  0.000000e+00
# 25%                     2052.250000          117.00000  5.191300e+04
# 50%                     5290.500000         1493.00000  2.949490e+05
# 75%                    19285.750000         5469.00000  7.583480e+05
# max                   305002.000000       113150.00000  4.349034e+06
#
#             tamponi  casi_testati  ingressi_terapia_intensiva  \
# count  3.387300e+04  3.271800e+04                27930.000000
# mean   7.916455e+06  2.233607e+06                    2.096885
# std    1.027457e+07  2.503109e+06                    4.782130
# min    0.000000e+00  3.482000e+03                   -2.000000
# 25%    7.702590e+05  4.203338e+05                    0.000000
# 50%    3.839317e+06  1.260532e+06                    0.000000
# 75%    1.126931e+07  3.035685e+06                    2.000000
# max    4.745869e+07  2.800304e+07                   86.000000
#
#        totale_positivi_test_molecolare  \
# count                     2.702700e+04
# mean                      3.779755e+05
# std                       3.863480e+05
# min                       7.382000e+03
# 25%                       7.816700e+04
# 50%                       2.234070e+05
# 75%                       5.199055e+05
# max                       1.651393e+06
#
#        totale_positivi_test_antigenico_rapido  tamponi_test_molecolare  \
# count                            2.702700e+04             2.702700e+04
# mean                             4.782322e+05             4.068773e+06
# std                              6.025746e+05             4.019196e+06
# min                              0.000000e+00             6.615200e+04
# 25%                              1.502650e+04             9.400750e+05
# 50%                              2.170110e+05             2.478104e+06
# 75%                              8.215730e+05             5.474046e+06
# max                              2.794847e+06             1.722971e+07
#
#        tamponi_test_antigenico_rapido
# count                    2.702700e+04
# mean                     5.737174e+06
# std                      7.010659e+06
# min                      0.000000e+00
# 25%                      6.580815e+05
# 50%                      3.166476e+06
# 75%                      8.920632e+06
# max                      3.022898e+07
#
# [8 rows x 22 columns]

# %% [markdown]
# ###   .drop()

# %% [markdown]
# [.drop()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)

# %%
len(covid_regions_df.columns)
# Out:
# 30

# %%
covid_regions_df.drop(['codice_regione', 'lat','long'], axis=1, inplace=True)

# %%
len(covid_regions_df.columns)
# Out:
# 27

# %% [markdown]
# ### .info()

# %% [markdown]
# [.info()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html)

# %%
covid_regions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33873 entries, 0 to 33872
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   data                                    33873 non-null  object
#  1   stato                                   33873 non-null  object
#  2   denominazione_regione                   33873 non-null  object
#  3   ricoverati_con_sintomi                  33873 non-null  int64
#  4   terapia_intensiva                       33873 non-null  int64
#  5   totale_ospedalizzati                    33873 non-null  int64
#  6   isolamento_domiciliare                  33873 non-null  int64
#  7   totale_positivi                         33873 non-null  int64
#  8   variazione_totale_positivi              33873 non-null  int64
#  9   nuovi_positivi                          33873 non-null  int64
#  10  dimessi_guariti                         33873 non-null  int64
#  11  deceduti                                33873 non-null  int64
#  12  casi_da_sospetto_diagnostico            3402 non-null   float64
#  13  casi_da_screening                       3402 non-null   float64
#  14  totale_casi                             33873 non-null  int64
#  15  tamponi                                 33873 non-null  int64
#  16  casi_testati                            32718 non-null  float64
#  17  note                                    8630 non-null   object
#  18  ingressi_terapia_intensiva              27930 non-null  float64
#  19  note_test                               200 non-null    object
#  20  note_casi                               4282 non-null   object
#  21  totale_positivi_test_molecolare         27027 non-null  float64
#  22  totale_positivi_test_antigenico_rapido  27027 non-null  float64
#  23  tamponi_test_molecolare                 27027 non-null  float64
#  24  tamponi_test_antigenico_rapido          27027 non-null  float64
#  25  codice_nuts_1                           27027 non-null  object
#  26  codice_nuts_2                           27027 non-null  object
# dtypes: float64(8), int64(11), object(8)
# memory usage: 7.0+ MB

# %% [markdown]
# ### missing values

# %% [markdown]
# [.isnull()](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html)

# %%
covid_regions_df.isnull().sum(0)
# Out:
# data                                          0
# stato                                         0
# denominazione_regione                         0
# ricoverati_con_sintomi                        0
# terapia_intensiva                             0
# totale_ospedalizzati                          0
# isolamento_domiciliare                        0
# totale_positivi                               0
# variazione_totale_positivi                    0
# nuovi_positivi                                0
# dimessi_guariti                               0
# deceduti                                      0
# casi_da_sospetto_diagnostico              30471
# casi_da_screening                         30471
# totale_casi                                   0
# tamponi                                       0
# casi_testati                               1155
# note                                      25243
# ingressi_terapia_intensiva                 5943
# note_test                                 33673
# note_casi                                 29591
# totale_positivi_test_molecolare            6846
# totale_positivi_test_antigenico_rapido     6846
# tamponi_test_molecolare                    6846
# tamponi_test_antigenico_rapido             6846
# codice_nuts_1                              6846
# codice_nuts_2                              6846
# dtype: int64

# %% [markdown]
# ### sort_values
#
# This is the first example of "data transformation" with a pandas dataframe.
#
# If ```inplace=True``` is omitted the dataframe is not reordered. --> this argument is present in several pandas dataframe's function.

# %% [markdown]
# [.sort_values()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)

# %%
covid_regions_df.sort_values(by=['deceduti'], ascending=False)# , inplace=True)
# Out:
#                       data stato denominazione_regione  \
# 33860  2024-07-24T17:00:00   ITA             Lombardia
# 33839  2024-07-23T17:00:00   ITA             Lombardia
# 33818  2024-07-22T17:00:00   ITA             Lombardia
# 33797  2024-07-21T17:00:00   ITA             Lombardia
# 33776  2024-07-20T17:00:00   ITA             Lombardia
# ...                    ...   ...                   ...
# 210    2020-03-05T17:00:00   ITA               Abruzzo
# 211    2020-03-05T17:00:00   ITA            Basilicata
# 212    2020-03-05T17:00:00   ITA              Calabria
# 213    2020-03-05T17:00:00   ITA              Campania
# 0      2020-02-24T18:00:00   ITA               Abruzzo
#
#        ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# 33860                     114                  0                   114
# 33839                     104                  0                   104
# 33818                      92                  0                    92
# 33797                      93                  0                    93
# 33776                      84                  3                    87
# ...                       ...                ...                   ...
# 210                         8                  0                     8
# 211                         0                  0                     0
# 212                         1                  0                     1
# 213                        12                  0                    12
# 0                           0                  0                     0
#
#        isolamento_domiciliare  totale_positivi  variazione_totale_positivi  \
# 33860                    2754             2868                          53
# 33839                    2711             2815                        -108
# 33818                    2831             2923                          92
# 33797                    2738             2831                         166
# 33776                    2578             2665                         183
# ...                       ...              ...                         ...
# 210                         0                8                           1
# 211                         1                1                           0
# 212                         1                2                           1
# 213                        33               45                          14
# 0                           0                0                           0
#
#        nuovi_positivi  ...  note  ingressi_terapia_intensiva  note_test  \
# 33860             529  ...   NaN                         0.0        NaN
# 33839             645  ...   NaN                         0.0        NaN
# 33818             106  ...   NaN                         0.0        NaN
# 33797             191  ...   NaN                         0.0        NaN
# 33776             317  ...   NaN                         0.0        NaN
# ...               ...  ...   ...                         ...        ...
# 210                 1  ...   NaN                         NaN        NaN
# 211                 0  ...   NaN                         NaN        NaN
# 212                 1  ...   NaN                         NaN        NaN
# 213                14  ...   NaN                         NaN        NaN
# 0                   0  ...   NaN                         NaN        NaN
#
#        note_casi  totale_positivi_test_molecolare  \
# 33860        NaN                        1554187.0
# 33839        NaN                        1554153.0
# 33818        NaN                        1554101.0
# 33797        NaN                        1554096.0
# 33776        NaN                        1554086.0
# ...          ...                              ...
# 210          NaN                              NaN
# 211          NaN                              NaN
# 212          NaN                              NaN
# 213          NaN                              NaN
# 0            NaN                              NaN
#
#        totale_positivi_test_antigenico_rapido  tamponi_test_molecolare  \
# 33860                               2794847.0               17229706.0
# 33839                               2794352.0               17229557.0
# 33818                               2793759.0               17229339.0
# 33797                               2793658.0               17229246.0
# 33776                               2793477.0               17229150.0
# ...                                       ...                      ...
# 210                                       NaN                      NaN
# 211                                       NaN                      NaN
# 212                                       NaN                      NaN
# 213                                       NaN                      NaN
# 0                                         NaN                      NaN
#
#       tamponi_test_antigenico_rapido  codice_nuts_1 codice_nuts_2
# 33860                     30228983.0            ITC          ITC4
# 33839                     30226274.0            ITC          ITC4
# 33818                     30223183.0            ITC          ITC4
# 33797                     30222419.0            ITC          ITC4
# 33776                     30221223.0            ITC          ITC4
# ...                              ...            ...           ...
# 210                              NaN            NaN           NaN
# 211                              NaN            NaN           NaN
# 212                              NaN            NaN           NaN
# 213                              NaN            NaN           NaN
# 0                                NaN            NaN           NaN
#
# [33873 rows x 27 columns]

# %% [markdown]
# ### correlations

# %% [markdown]
# [.corr()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html)

# %%
covid_provinces_df_numeric = covid_provinces_df.select_dtypes(include=[float, int])

covid_provinces_df_numeric.corr()
# Out:
#                   codice_regione  codice_provincia       lat      long  \
# codice_regione          1.000000          0.046331 -0.930668  0.664040
# codice_provincia        0.046331          1.000000 -0.655025  0.484583
# lat                    -0.930668         -0.655025  1.000000 -0.611093
# long                    0.664040          0.484583 -0.611093  1.000000
# totale_casi            -0.073796         -0.309140  0.061825 -0.018341
#
#                   totale_casi
# codice_regione      -0.073796
# codice_provincia    -0.309140
# lat                  0.061825
# long                -0.018341
# totale_casi          1.000000

# %% [markdown]
# ---
#
# <a id='section3'></a>
# ## 4. Data selection
#
# ---
# Here we will see how to "reduce" the data present in a dataframe acting on the dataframe's columns and on the rows  as well.

# %% [markdown]
# ### column selection

# %%
covid_regions_df.columns
# Out:
# Index(['data', 'stato', 'denominazione_regione', 'ricoverati_con_sintomi',
#        'terapia_intensiva', 'totale_ospedalizzati', 'isolamento_domiciliare',
#        'totale_positivi', 'variazione_totale_positivi', 'nuovi_positivi',
#        'dimessi_guariti', 'deceduti', 'casi_da_sospetto_diagnostico',
#        'casi_da_screening', 'totale_casi', 'tamponi', 'casi_testati', 'note',
#        'ingressi_terapia_intensiva', 'note_test', 'note_casi',
#        'totale_positivi_test_molecolare',
#        'totale_positivi_test_antigenico_rapido', 'tamponi_test_molecolare',
#        'tamponi_test_antigenico_rapido', 'codice_nuts_1', 'codice_nuts_2'],
#       dtype='object')

# %%
covid_regions_df['data']
# Out:
# 0        2020-02-24T18:00:00
# 1        2020-02-24T18:00:00
# 2        2020-02-24T18:00:00
# 3        2020-02-24T18:00:00
# 4        2020-02-24T18:00:00
#                 ...
# 33868    2024-07-24T17:00:00
# 33869    2024-07-24T17:00:00
# 33870    2024-07-24T17:00:00
# 33871    2024-07-24T17:00:00
# 33872    2024-07-24T17:00:00
# Name: data, Length: 33873, dtype: object

# %% [markdown]
# Pay attention of avoid column names with spaces and avoid functions/attributes implemented in the pandas dataframe object

# %%
covid_regions_df.data
# Out:
# 0        2020-02-24T18:00:00
# 1        2020-02-24T18:00:00
# 2        2020-02-24T18:00:00
# 3        2020-02-24T18:00:00
# 4        2020-02-24T18:00:00
#                 ...
# 33868    2024-07-24T17:00:00
# 33869    2024-07-24T17:00:00
# 33870    2024-07-24T17:00:00
# 33871    2024-07-24T17:00:00
# 33872    2024-07-24T17:00:00
# Name: data, Length: 33873, dtype: object

# %% [markdown]
# #### Pandas series
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.html

# %%
type(covid_regions_df['data'])
# Out:
# pandas.core.series.Series

# %%
covid_regions_df[['denominazione_regione','totale_positivi']]
# Out:
#       denominazione_regione  totale_positivi
# 0                   Abruzzo                0
# 1                Basilicata                0
# 2                  Calabria                0
# 3                  Campania                0
# 4            Emilia-Romagna               18
# ...                     ...              ...
# 33868               Sicilia             1252
# 33869               Toscana             1235
# 33870                Umbria              813
# 33871         Valle d'Aosta               10
# 33872                Veneto            10596
#
# [33873 rows x 2 columns]

# %% [markdown]
# ### row selection

# %% [markdown]
# * __loc__ gets rows (and/or columns) with particular __labels__ (if indexes are strings uses indexes labes).
#
# * __iloc__ gets rows (and/or columns) at integer locations (always numbers).

# %%
covid_regions_df.index.values
# Out:
# array([    0,     1,     2, ..., 33870, 33871, 33872])

# %% [markdown]
# [.loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)

# %%
covid_regions_df.loc[1:3]
# Out:
#                   data stato denominazione_regione  ricoverati_con_sintomi  \
# 1  2020-02-24T18:00:00   ITA            Basilicata                       0
# 2  2020-02-24T18:00:00   ITA              Calabria                       0
# 3  2020-02-24T18:00:00   ITA              Campania                       0
#
#    terapia_intensiva  totale_ospedalizzati  isolamento_domiciliare  \
# 1                  0                     0                       0
# 2                  0                     0                       0
# 3                  0                     0                       0
#
#    totale_positivi  variazione_totale_positivi  nuovi_positivi  ...  note  \
# 1                0                           0               0  ...   NaN
# 2                0                           0               0  ...   NaN
# 3                0                           0               0  ...   NaN
#
#    ingressi_terapia_intensiva  note_test  note_casi  \
# 1                         NaN        NaN        NaN
# 2                         NaN        NaN        NaN
# 3                         NaN        NaN        NaN
#
#    totale_positivi_test_molecolare  totale_positivi_test_antigenico_rapido  \
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
#
#    tamponi_test_molecolare tamponi_test_antigenico_rapido  codice_nuts_1  \
# 1                      NaN                            NaN            NaN
# 2                      NaN                            NaN            NaN
# 3                      NaN                            NaN            NaN
#
#   codice_nuts_2
# 1           NaN
# 2           NaN
# 3           NaN
#
# [3 rows x 27 columns]

# %%
covid_regions_df.loc[12557]
# Out:
# data                                      2021-10-13T17:00:00
# stato                                                     ITA
# denominazione_regione                                  Veneto
# ricoverati_con_sintomi                                    144
# terapia_intensiva                                          33
# totale_ospedalizzati                                      177
# isolamento_domiciliare                                   8946
# totale_positivi                                          9123
# variazione_totale_positivi                               -108
# nuovi_positivi                                            348
# dimessi_guariti                                        452440
# deceduti                                                11799
# casi_da_sospetto_diagnostico                              NaN
# casi_da_screening                                         NaN
# totale_casi                                            473362
# tamponi                                              12432920
# casi_testati                                        2136283.0
# note                                                      NaN
# ingressi_terapia_intensiva                                2.0
# note_test                                                 NaN
# note_casi                                                 NaN
# totale_positivi_test_molecolare                      458582.0
# totale_positivi_test_antigenico_rapido                14780.0
# tamponi_test_molecolare                             6870353.0
# tamponi_test_antigenico_rapido                      5562567.0
# codice_nuts_1                                             ITH
# codice_nuts_2                                            ITH3
# Name: 12557, dtype: object

# %% [markdown]
# #### Mask

# %%
covid_provinces_df['denominazione_regione']=='Emilia-Romagna'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 237770    False
# 237771    False
# 237772    False
# 237773    False
# 237774    False
# Name: denominazione_regione, Length: 237775, dtype: bool

# %%
m = covid_provinces_df['denominazione_regione']=='Emilia-Romagna'

# %%
m.unique()
# Out:
# array([False,  True])

# %%
covid_provinces_df[covid_provinces_df['denominazione_regione']=='Emilia-Romagna'].head(3)
# Out:
#                    data stato  codice_regione denominazione_regione  \
# 20  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# 21  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# 22  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
#
#     codice_provincia denominazione_provincia sigla_provincia        lat  \
# 20                33                Piacenza              PC  45.051935
# 21                34                   Parma              PR  44.801074
# 22                35      Reggio nell'Emilia              RE  44.697353
#
#          long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 20   9.692633            0  NaN           NaN           NaN           NaN
# 21  10.328350            0  NaN           NaN           NaN           NaN
# 22  10.630080            0  NaN           NaN           NaN           NaN

# %%
covid_provinces_df[(covid_provinces_df['denominazione_regione']=='Emilia-Romagna') & (covid_provinces_df['totale_casi'] > 1000)].head(3)
# Out:
#                      data stato  codice_regione denominazione_regione  \
# 2580  2020-03-15T17:00:00   ITA               8        Emilia-Romagna
# 2708  2020-03-16T17:00:00   ITA               8        Emilia-Romagna
# 2836  2020-03-17T17:00:00   ITA               8        Emilia-Romagna
#
#       codice_provincia denominazione_provincia sigla_provincia        lat  \
# 2580                33                Piacenza              PC  45.051935
# 2708                33                Piacenza              PC  45.051935
# 2836                33                Piacenza              PC  45.051935
#
#           long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 2580  9.692633         1012  NaN           NaN           NaN           NaN
# 2708  9.692633         1073  NaN           NaN           NaN           NaN
# 2836  9.692633         1204  NaN           NaN           NaN           NaN

# %% [markdown]
# actually what happens ....

# %%
m1 = covid_provinces_df['denominazione_regione']=='Emilia-Romagna'
m2 = covid_provinces_df['totale_casi'] > 1000

# %%
covid_provinces_df[m1 & m2].head(3)
# Out:
#                      data stato  codice_regione denominazione_regione  \
# 2580  2020-03-15T17:00:00   ITA               8        Emilia-Romagna
# 2708  2020-03-16T17:00:00   ITA               8        Emilia-Romagna
# 2836  2020-03-17T17:00:00   ITA               8        Emilia-Romagna
#
#       codice_provincia denominazione_provincia sigla_provincia        lat  \
# 2580                33                Piacenza              PC  45.051935
# 2708                33                Piacenza              PC  45.051935
# 2836                33                Piacenza              PC  45.051935
#
#           long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 2580  9.692633         1012  NaN           NaN           NaN           NaN
# 2708  9.692633         1073  NaN           NaN           NaN           NaN
# 2836  9.692633         1204  NaN           NaN           NaN           NaN

# %% [markdown]
# # .query
#
# The best choice if you have several conditions to be applied on the row selection.

# %% [markdown]
# [.query()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)

# %%
covid_provinces_df.query("(denominazione_regione == 'Emilia-Romagna') and (totale_casi > 1000)").head(3)
# Out:
#                      data stato  codice_regione denominazione_regione  \
# 2580  2020-03-15T17:00:00   ITA               8        Emilia-Romagna
# 2708  2020-03-16T17:00:00   ITA               8        Emilia-Romagna
# 2836  2020-03-17T17:00:00   ITA               8        Emilia-Romagna
#
#       codice_provincia denominazione_provincia sigla_provincia        lat  \
# 2580                33                Piacenza              PC  45.051935
# 2708                33                Piacenza              PC  45.051935
# 2836                33                Piacenza              PC  45.051935
#
#           long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 2580  9.692633         1012  NaN           NaN           NaN           NaN
# 2708  9.692633         1073  NaN           NaN           NaN           NaN
# 2836  9.692633         1204  NaN           NaN           NaN           NaN

# %%
nc = 1000
covid_provinces_df.query("(denominazione_regione == 'Emilia-Romagna') and (totale_casi > @nc)").head(3)
# Out:
#                      data stato  codice_regione denominazione_regione  \
# 2580  2020-03-15T17:00:00   ITA               8        Emilia-Romagna
# 2708  2020-03-16T17:00:00   ITA               8        Emilia-Romagna
# 2836  2020-03-17T17:00:00   ITA               8        Emilia-Romagna
#
#       codice_provincia denominazione_provincia sigla_provincia        lat  \
# 2580                33                Piacenza              PC  45.051935
# 2708                33                Piacenza              PC  45.051935
# 2836                33                Piacenza              PC  45.051935
#
#           long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 2580  9.692633         1012  NaN           NaN           NaN           NaN
# 2708  9.692633         1073  NaN           NaN           NaN           NaN
# 2836  9.692633         1204  NaN           NaN           NaN           NaN

# %% [markdown]
# with f-strings

# %%
covid_provinces_df.query(f"(denominazione_regione == 'Emilia-Romagna') and (totale_casi > {nc})").head(3)
# Out:
#                      data stato  codice_regione denominazione_regione  \
# 2580  2020-03-15T17:00:00   ITA               8        Emilia-Romagna
# 2708  2020-03-16T17:00:00   ITA               8        Emilia-Romagna
# 2836  2020-03-17T17:00:00   ITA               8        Emilia-Romagna
#
#       codice_provincia denominazione_provincia sigla_provincia        lat  \
# 2580                33                Piacenza              PC  45.051935
# 2708                33                Piacenza              PC  45.051935
# 2836                33                Piacenza              PC  45.051935
#
#           long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 2580  9.692633         1012  NaN           NaN           NaN           NaN
# 2708  9.692633         1073  NaN           NaN           NaN           NaN
# 2836  9.692633         1204  NaN           NaN           NaN           NaN

# %% [markdown]
# ### AND or OR

# %%
covid_provinces_df.query(f"(denominazione_regione == 'Emilia-Romagna') or (totale_casi > {nc})").head(3)
# Out:
#                    data stato  codice_regione denominazione_regione  \
# 20  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# 21  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# 22  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
#
#     codice_provincia denominazione_provincia sigla_provincia        lat  \
# 20                33                Piacenza              PC  45.051935
# 21                34                   Parma              PR  44.801074
# 22                35      Reggio nell'Emilia              RE  44.697353
#
#          long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 20   9.692633            0  NaN           NaN           NaN           NaN
# 21  10.328350            0  NaN           NaN           NaN           NaN
# 22  10.630080            0  NaN           NaN           NaN           NaN

# %% [markdown]
# #### .isin
# --> avoid OR OR OR OR OR OR....

# %% [markdown]
# [.isin()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html)

# %%
covid_provinces_df['denominazione_regione'].unique()
# Out:
# array(['Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Emilia-Romagna',
#        'Friuli Venezia Giulia', 'Lazio', 'Liguria', 'Lombardia', 'Marche',
#        'Molise', 'P.A. Bolzano', 'P.A. Trento', 'Piemonte', 'Puglia',
#        'Sardegna', 'Sicilia', 'Toscana', 'Umbria', "Valle d'Aosta",
#        'Veneto'], dtype=object)

# %%
regions = ['Abruzzo', 'Basilicata', 'Calabria', 'Campania']

# %%
covid_provinces_df[covid_provinces_df['denominazione_regione'].isin(regions)].head(2)
# Out:
#                   data stato  codice_regione denominazione_regione  \
# 0  2020-02-24T18:00:00   ITA              13               Abruzzo
# 1  2020-02-24T18:00:00   ITA              13               Abruzzo
#
#    codice_provincia denominazione_provincia sigla_provincia        lat  \
# 0                66                L'Aquila              AQ  42.351222
# 1                67                  Teramo              TE  42.658918
#
#         long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 0  13.398438            0  NaN           NaN           NaN           NaN
# 1  13.704400            0  NaN           NaN           NaN           NaN

# %%
covid_provinces_df[covid_provinces_df['denominazione_regione'].isin(regions)].tail(2)
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 237648  2024-07-24T17:00:00   ITA              15              Campania
# 237649  2024-07-24T17:00:00   ITA              15              Campania
#
#         codice_provincia               denominazione_provincia  \
# 237648               883    Fuori Regione / Provincia Autonoma
# 237649               983  In fase di definizione/aggiornamento
#
#        sigla_provincia  lat  long  totale_casi note codice_nuts_1  \
# 237648             NaN  NaN   NaN        18123  NaN           ITF
# 237649             NaN  NaN   NaN        25128  NaN           ITF
#
#        codice_nuts_2 codice_nuts_3
# 237648          ITF3           NaN
# 237649          ITF3           NaN

# %% [markdown]
# ---
#
# <a id='section4'></a>
# ## 5. Data manipulation
#
# ---
#
# Here we will see how is possible to modify the values stored in a pandas dataframe and how to add new data combining one or more data from the same row, from multiple columns or from variables/object defined outside to the pandas dataframe.

# %% [markdown]
# ### fill NA/NaN values

# %% [markdown]
# [.fillna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)

# %%
covid_provinces_df['sigla_provincia'] = covid_provinces_df['sigla_provincia'].fillna(0)

# %%
covid_provinces_df.fillna(0, inplace=True)

# %% [markdown]
# ### change columns data types

# %% [markdown]
# #### to_numeric
# convert one or more columns of a DataFrame to numeric values

# %% [markdown]
# [.to_numeric()](https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html)

# %%
s = pd.Series(["8", 6, "7.5", 3, "0.9"]) # mixed string and numeric values
s
# Out:
# 0      8
# 1      6
# 2    7.5
# 3      3
# 4    0.9
# dtype: object

# %%
pd.to_numeric(s) # convert everything to float values
# Out:
# 0    8.0
# 1    6.0
# 2    7.5
# 3    3.0
# 4    0.9
# dtype: float64

# %% [markdown]
# #### astype()
# general purpose

# %% [markdown]
# [.astype()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html)

# %%
s.astype(str)
# Out:
# 0      8
# 1      6
# 2    7.5
# 3      3
# 4    0.9
# dtype: object

# %% [markdown]
# ### group-by
# sql-like concept

# %% [markdown]
# [.groupby()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)

# %% [markdown]
# https://goc.egi.eu/portal/index.php?Page_Type=Downtime&id=31280
#
# ![groupby.png](attachment:groupby.png)

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data': range(6)}, columns=['key', 'data'])
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %% [markdown]
# # Apply a function to each row of the dataframe, thas has in input some of the dataframe columns
# ### example:
# What if we want to add the population for each region for reach row as a new column ?

# %% [markdown]
# #### create a dictionary from a pandas dataframe

# %%
populations = {
    'Lombardia' : 10000000,
    'Lazio' : 5000000,
    'Campania' : 6000000,
    'Veneto' : 4000000,
    'Sicilia' : 5000000,
    'Emilia-Romagna' : 4000000,
    'Piemonte' : 4000000,
    'Puglia' : 4000000,
    'Toscana' : 4000000,
    'Calabria' : 4000000,
    'Sardegna' : 4000000,
    'Liguria' : 4000000,
    'Marche' : 4000000,
    'Abruzzo' : 4000000,
    'Friuli Venezia Giulia' : 4000000,
    'Trentino-Alto Adige' : 4000000,
    'Umbria' : 4000000,
    'Basilicata' : 4000000,
    'Molise' : 4000000,
    'Valle d\'Aosta' : 4000000,
    'P.A. Bolzano' : 5000000,
    'P.A. Trento' : 5000000
}

# %%
covid_provinces_df.tail(3)
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 237772  2024-07-24T17:00:00   ITA               5                Veneto
# 237773  2024-07-24T17:00:00   ITA               5                Veneto
# 237774  2024-07-24T17:00:00   ITA               5                Veneto
#
#         codice_provincia               denominazione_provincia  \
# 237772                29                                Rovigo
# 237773               899    Fuori Regione / Provincia Autonoma
# 237774               999  In fase di definizione/aggiornamento
#
#        sigla_provincia        lat      long  totale_casi note codice_nuts_1  \
# 237772              RO  45.071073  11.79007       127205    0           ITH
# 237773               0   0.000000   0.00000        40246    0           ITH
# 237774               0   0.000000   0.00000        13075    0           ITH
#
#        codice_nuts_2 codice_nuts_3
# 237772          ITH3         ITH37
# 237773          ITH3             0
# 237774          ITH3             0

# %%
covid_provinces_df['denominazione_regione'].unique()
# Out:
# array(['Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Emilia-Romagna',
#        'Friuli Venezia Giulia', 'Lazio', 'Liguria', 'Lombardia', 'Marche',
#        'Molise', 'P.A. Bolzano', 'P.A. Trento', 'Piemonte', 'Puglia',
#        'Sardegna', 'Sicilia', 'Toscana', 'Umbria', "Valle d'Aosta",
#        'Veneto'], dtype=object)

# %% [markdown]
# ## Avoid this:

# %%
# %%time
covid_provinces_df['population'] = 0
for index, row in covid_provinces_df.iterrows():
    p = populations[row['denominazione_regione']]
    covid_provinces_df.at[index,'population'] = p
# Out:
# CPU times: user 16.3 s, sys: 56.1 ms, total: 16.3 s
# Wall time: 16.3 s

# %% [markdown]
# ### Best practice
#
# This is the best trade off between flexibility, easy sintax and performance.

# %% [markdown]
# #### apply

# %% [markdown]
# [.apply()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html)

# %%
def get_population(populations, rname): #rname = region name
    p = populations[rname]
    return p

# %%
# %%time
covid_provinces_df['population'] = covid_provinces_df.apply(lambda row: get_population(populations, row['denominazione_regione']), axis=1)
# Out:
# CPU times: user 893 ms, sys: 32.1 ms, total: 925 ms
# Wall time: 924 ms

# %%
def frac(cases, npeople):
    return cases/npeople

# %%
# %%time
covid_provinces_df['frac'] = covid_provinces_df.apply(lambda row: frac(row['totale_casi'], row['population']), axis=1)
# Out:
# CPU times: user 1.22 s, sys: 52 ms, total: 1.27 s
# Wall time: 1.27 s

# %%
covid_provinces_df['frac'].tail(3)
# Out:
# 237772    0.031801
# 237773    0.010061
# 237774    0.003269
# Name: frac, dtype: float64

# %%
# %%time
covid_provinces_df['frac'] = covid_provinces_df['totale_casi']/covid_provinces_df['population']
# Out:
# CPU times: user 3.56 ms, sys: 280 µs, total: 3.84 ms
# Wall time: 2.9 ms

# %%
covid_provinces_df['frac'].tail(3)
# Out:
# 237772    0.031801
# 237773    0.010061
# 237774    0.003269
# Name: frac, dtype: float64

# %% [markdown]
# ### eval
# Nice sintax and quite optimized computation.

# %% [markdown]
# [.eval()](https://pandas.pydata.org/docs/reference/api/pandas.eval.html)

# %%
# %%time
covid_provinces_df['frac'] = covid_provinces_df.eval('totale_casi / population')
# Out:
# CPU times: user 4.48 ms, sys: 4.17 ms, total: 8.64 ms
# Wall time: 7.38 ms

# %%
covid_provinces_df['frac'].tail(3)
# Out:
# 237772    0.031801
# 237773    0.010061
# 237774    0.003269
# Name: frac, dtype: float64

# %% [markdown]
# [.dtypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html)

# %%
covid_provinces_df.dtypes
# Out:
# data                        object
# stato                       object
# codice_regione               int64
# denominazione_regione       object
# codice_provincia             int64
# denominazione_provincia     object
# sigla_provincia             object
# lat                        float64
# long                       float64
# totale_casi                  int64
# note                        object
# codice_nuts_1               object
# codice_nuts_2               object
# codice_nuts_3               object
# population                   int64
# frac                       float64
# dtype: object

# %% [markdown]
# [.to_datetime()](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
covid_provinces_df['data']= pd.to_datetime(covid_provinces_df['data'])

# %% [markdown]
# [.max()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.max.html)

# %%
last_update = covid_provinces_df[covid_provinces_df['data'] == covid_provinces_df['data'].max()]

# %%
last_update.head(3)
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 237626 2024-07-24 17:00:00   ITA              13               Abruzzo
# 237627 2024-07-24 17:00:00   ITA              13               Abruzzo
# 237628 2024-07-24 17:00:00   ITA              13               Abruzzo
#
#         codice_provincia denominazione_provincia sigla_provincia        lat  \
# 237626                66                L'Aquila              AQ  42.351222
# 237627                67                  Teramo              TE  42.658918
# 237628                68                 Pescara              PE  42.464584
#
#              long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3  \
# 237626  13.398438       139589    0           ITF          ITF1         ITF11
# 237627  13.704400       164469    0           ITF          ITF1         ITF12
# 237628  14.213648       163407    0           ITF          ITF1         ITF13
#
#         population      frac
# 237626     4000000  0.034897
# 237627     4000000  0.041117
# 237628     4000000  0.040852
